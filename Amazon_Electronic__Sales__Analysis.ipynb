# %% [markdown]
# <a href="https://colab.research.google.com/github/Mehfoozans2525/Mehfoozans2525/blob/main/Amazon_Electronic__Sales__Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import seaborn as sns
dataset = pd.read_csv('https://raw.githubusercontent.com/ManuhIsMe/Product_Sales_Analysis_With_Python/main/Product_Analysis/electronics.csv')
dataset.head()
# Out:
#    item_id  user_id  rating   timestamp model_attr                category  \
# 0        0        0     5.0  1999-06-13     Female  Portable Audio & Video
# 1        0        1     5.0  1999-06-14     Female  Portable Audio & Video
# 2        0        2     3.0  1999-06-17     Female  Portable Audio & Video
# 3        0        3     1.0  1999-07-01     Female  Portable Audio & Video
# 4        0        4     2.0  1999-07-06     Female  Portable Audio & Video
#
#   brand  year user_attr  split
# 0   NaN  1999       NaN      0
# 1   NaN  1999       NaN      0
# 2   NaN  1999       NaN      0
# 3   NaN  1999       NaN      0
# 4   NaN  1999       NaN      0

# %%
dataset.tail()
# Out:
#          item_id  user_id  rating   timestamp model_attr  \
# 1292949     9478  1157628     1.0  2018-09-26     Female
# 1292950     9435  1157629     5.0  2018-09-26     Female
# 1292951     9305  1157630     3.0  2018-09-26     Female
# 1292952     9303  1157631     5.0  2018-09-29       Male
# 1292953     9478  1157632     1.0  2018-10-01     Female
#
#                         category       brand  year user_attr  split
# 1292949               Headphones  Etre Jeune  2017       NaN      0
# 1292950  Computers & Accessories         NaN  2017       NaN      0
# 1292951  Computers & Accessories         NaN  2016       NaN      0
# 1292952               Headphones         NaN  2018       NaN      0
# 1292953               Headphones  Etre Jeune  2017    Female      0

# %%
dataset.shape
# Out:
# (1292954, 10)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1292954 entries, 0 to 1292953
# Data columns (total 10 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   item_id     1292954 non-null  int64
#  1   user_id     1292954 non-null  int64
#  2   rating      1292954 non-null  float64
#  3   timestamp   1292954 non-null  object
#  4   model_attr  1292954 non-null  object
#  5   category    1292954 non-null  object
#  6   brand       331120 non-null   object
#  7   year        1292954 non-null  int64
#  8   user_attr   174124 non-null   object
#  9   split       1292954 non-null  int64
# dtypes: float64(1), int64(4), object(5)
# memory usage: 98.6+ MB

# %%
from datetime import datetime

pd.to_datetime(dataset['timestamp'])
# Out:
# 0         1999-06-13
# 1         1999-06-14
# 2         1999-06-17
# 3         1999-07-01
# 4         1999-07-06
#              ...
# 1292949   2018-09-26
# 1292950   2018-09-26
# 1292951   2018-09-26
# 1292952   2018-09-29
# 1292953   2018-10-01
# Name: timestamp, Length: 1292954, dtype: datetime64[ns]

# %%
dataset['brand'] = dataset['brand'].astype(str)

# %%
dataset['category'] = dataset['category'].astype(str)

# %%
dataset['rating'] = dataset['rating'].astype(float)

# %%
dataset['user_id'] = dataset['user_id'].astype(str)

# %%
dataset['item_id'] = dataset['item_id'].astype(str)

# %%
dataset.describe()
# Out:
#              rating          year         split
# count  1.292954e+06  1.292954e+06  1.292954e+06
# mean   4.051482e+00  2.012938e+03  1.747587e-01
# std    1.379732e+00  2.643513e+00  5.506810e-01
# min    1.000000e+00  1.999000e+03  0.000000e+00
# 25%    4.000000e+00  2.012000e+03  0.000000e+00
# 50%    5.000000e+00  2.014000e+03  0.000000e+00
# 75%    5.000000e+00  2.015000e+03  0.000000e+00
# max    5.000000e+00  2.018000e+03  2.000000e+00

# %%
dataset.nunique()
# Out:
# item_id          9560
# user_id       1157633
# rating              5
# timestamp        6354
# model_attr          3
# category           10
# brand              51
# year               20
# user_attr           2
# split               3
# dtype: int64

# %%
dataset.duplicated().sum()
# Out:
# 0

# %%
dataset.isnull().sum()
# Out:
# item_id             0
# user_id             0
# rating              0
# timestamp           0
# model_attr          0
# category            0
# brand               0
# year                0
# user_attr     1118830
# split               0
# dtype: int64

# %%
print("FINDING ANSWERS WITH THE DATA WE HAVE IN OUR AMAZON ELECTRONIC SALES DATASET")
# Out:
# FINDING ANSWERS WITH THE DATA WE HAVE IN OUR AMAZON ELECTRONIC SALES DATASET

# %%
sns.countplot(x='rating', data=dataset)
# Out:
# <Axes: xlabel='rating', ylabel='count'>

# %%
dataset['year'] = pd.DatetimeIndex(dataset['timestamp']).year

dataset.groupby('year')['rating'].count().plot(kind='bar')
# Out:
# <Axes: xlabel='year'>

# %%
dataset_2015 = dataset[dataset['year'] == 2015]

dataset_2015.groupby('brand')['rating'].count().sort_values(ascending=False).head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='brand'>

# %%
dataset[dataset['year'] == 2016].groupby('brand')['rating'].count().sort_values(ascending=False).head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='brand'>

# %%
dataset[dataset['year'] == 2017].groupby('brand')['rating'].count().sort_values(ascending=False).head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='brand'>

# %%
dataset[dataset['year'] == 2018].groupby('brand')['rating'].count().sort_values(ascending=False).head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='brand'>

# %%
dataset[dataset['year'] == 2015].groupby('year')['rating'].count().plot(kind='bar')
# Out:
# <Axes: xlabel='year'>

# %%
dataset['month'] = pd.DatetimeIndex(dataset['timestamp']).month

dataset.groupby('month')['rating'].count().plot(kind='bar')
# Out:
# <Axes: xlabel='month'>

# %%
dataset.groupby('brand')['rating'].count().sort_values(ascending=False).head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='brand'>

# %%
dataset.groupby('category')['rating'].count().sort_values(ascending=False).head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='category'>

# %%
dataset.groupby('brand')['rating'].count().sort_values(ascending=True).head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='brand'>

# %%
dataset.groupby('category')['rating'].count().sort_values(ascending=True).head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='category'>

# %%
dataset.groupby('category')['rating'].count().sort_values(ascending=False).head(10).plot(kind='pie')
# Out:
# <Axes: ylabel='rating'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
dataset = pd.read_csv('https://raw.githubusercontent.com/ManuhIsMe/Product_Sales_Analysis_With_Python/main/Product_Analysis/electronics.csv')
dataset.groupby('brand')['rating'].count().sort_values(ascending=False).head(10).plot(kind='pie')
# Out:
# <Axes: ylabel='rating'>

# %%
sns.countplot(x='brand', data=dataset[dataset['year'] == 2018], order=dataset['brand'].value_counts().iloc[1:10].index)
# Out:
# <Axes: xlabel='brand', ylabel='count'>

# %%
sns.countplot(x='year', data=dataset)
# Out:
# <Axes: xlabel='year', ylabel='count'>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

average_ratings = dataset.groupby('year')['rating'].mean().reset_index()

plt.figure(figsize=(10, 6))  # Adjust the figure size if needed
sns.scatterplot(x='year', y='rating', data=average_ratings, color='green', marker='o')

plt.xlabel('Year')
plt.ylabel('Average Rating')
plt.title('Scatter Plot of Year vs Average Rating')

plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

correlation_matrix = dataset[['item_id', 'user_id', 'rating', 'split']].corr()

plt.figure(figsize=(10, 8))  # Adjust the figure size if needed
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=.4)

plt.title('Correlation Matrix Heatmap')

plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

columns_for_pairplot = ['rating', 'year', 'split']

sns.set(style="ticks")
pairplot = sns.pairplot(dataset[columns_for_pairplot], diag_kind='kde')

pairplot.fig.subplots_adjust(top=0.95)
pairplot.fig.suptitle('Pair Plot of Rating, Year, and Split')

plt.show()

# %% [markdown]
# 1) Data Overview:
#
# I loaded and preprocessed a dataset containing information about electronic product sales.
#
# 2) Data Exploration:
#
# I explored the dataset's shape, data types, and basic statistics.
# The dataset consists of over a million records, with various columns such as 'rating,' 'year,' 'category,' and 'brand.'
# You handled data types and ensured they were appropriate for each column.
#
# 3) Data Visualization:
#
# I created several data visualizations to gain insights:
# A count plot of ratings distribution.
# Bar plots showing the best-selling brands and products for each year.
# A bar plot showing the best sales year.
# A bar plot highlighting the best-selling brand in 2015.
# Bar plots displaying the top-selling brands and products for 2016, 2017, and 2018.
# A bar plot showing sales figures for 2015.
# A bar plot revealing the best sales month.
# Bar plots highlighting the top-selling brands and product categories.
# Bar plots revealing the least-selling brands and product categories.
# Pie charts representing category and brand percentage sales.
# Additional count plots.
#
# 4) Correlation Analysis:
#
# I generated a correlation matrix heatmap to visualize relationships between numerical columns. However, the heatmap code was not included in your original code.
#
# 5) Pair Plot:
#
# I created a pair plot to explore relationships between selected columns, such as 'year,' 'rating,' and 'split.'
#
# 6) Swarm Plot (Adjusted):
#
# I attempted to create a swarm plot to visualize the distribution of ratings across years, colored by category. However, there were issues with the code provided.
#
#                 •••Key Conclusions•••:
#
# The dataset provides valuable insights into electronic product sales over several years.
# Sales increased over the years, with 2015 being the best year for sales.
# The brand "Bose" consistently had strong sales performance.
# "Headphones" and "Computers & Accessories" were the top-selling categories.
# "Security and Surveillance" was the least-selling category.
# There were various ways to analyze and visualize the data, including distribution plots, time-based trends, and brand/category comparisons.
# The provided code demonstrates data preprocessing, visualization, and analysis techniques, but some adjustments were needed to make the code run smoothly.
# In conclusion, your code and analyses provide valuable insights into electronic product sales trends and performance, but some code adjustments and additional details in certain sections are required for a complete and accurate analysis.
#
#
#
#
#
# Bye Ma'am see you 😊
